# %%
import pandas as pd
import numpy as np

# %%
dfi1 = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Paper/2017/184_7.csv')
dfi1
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_15368/1976950362.py in <module>
# ----> 1 dfi1 = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Paper/2017/184_7.csv')
#       2 dfi1
#
# ~/.local/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
dfa = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie2017_Data_Public.csv')

# %%
dfa[(dfa.Sim == 182) & (dfa.Team==6)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_15368/2550342083.py in <module>
# ----> 1 dfa[(dfa.Sim == 182) & (dfa.Team==6)]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Sim'

# %%
df = pd.read_csv(f'/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie2017_calibrated_sm_hv.csv')
# Out:
# /home/poyraden/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (58,78,85) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df[['Date','Header_PFcor','PFcor','SerialNr']]
# Out:
#               Date  Header_PFcor    PFcor SerialNr
# 0       10/27/2017         3.367  3.36662  2Z21232
# 1       10/27/2017         3.367  3.36662  2Z21232
# 2       10/27/2017         3.367  3.36662  2Z21232
# 3       10/27/2017         3.367  3.36662  2Z21232
# 4       10/27/2017         3.367  3.36662  2Z21232
# ...            ...           ...      ...      ...
# 237066  10/20/2017         3.725  3.72498  6A33213
# 237067  10/20/2017         3.725  3.72498  6A33213
# 237068  10/20/2017         3.725  3.72498  6A33213
# 237069  10/20/2017         3.725  3.72498  6A33213
# 237070  10/20/2017         3.725  3.72498  6A33213
#
# [237071 rows x 4 columns]

# %%
df['Date']
df['Date2'] = pd.to_datetime(df['Date'])

# %%
df[['Date','Date2']]
# Out:
#               Date      Date2
# 0       10/27/2017 2017-10-27
# 1       10/27/2017 2017-10-27
# 2       10/27/2017 2017-10-27
# 3       10/27/2017 2017-10-27
# 4       10/27/2017 2017-10-27
# ...            ...        ...
# 237066  10/20/2017 2017-10-20
# 237067  10/20/2017 2017-10-20
# 237068  10/20/2017 2017-10-20
# 237069  10/20/2017 2017-10-20
# 237070  10/20/2017 2017-10-20
#
# [237071 rows x 2 columns]

# %%
print(list(df))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'Sim', 'Team', 'iB0', 'iB1', 'iB2', 'ENSCI', 'Sol', 'ADX', 'Buf', 'PO3', 'PO3_OPM', 'Tsim', 'Pair', 'IM', 'I_OPM_kom', 'I_OPM_jma', 'PFcor', 'TPext', 'Tpump_cor', 'unc_Tpump_cor', 'unc_Tpump', 'Tpump_cor.1', 'unc_Tpump_cor.1', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'PO3_calc', 'PO3_dqa', 'I_slow_conv_ib1_decay', 'Ifast_minib0_deconv', 'Ifast_minib0_deconv_ib1_decay', 'Ifast_minib0', 'Ifast_minib0_ib1_decay', 'Islow_conv', 'Ifast_deconv_ib1_decay', 'Ifast_minib0_deconv_sm10', 'Year', 'Unnamed: 0.1.1', 'index', 'Tact', 'Tair', 'Tinlet', 'TPint', 'I_Pump', 'VMRO3', 'VMRO3_OPM', 'ADif_PO3S', 'RDif_PO3S', 'Z', 'Header_Team', 'Header_Sim', 'Header_PFunc', 'Header_PFcor', 'Header_IB1', 'Simulator_RunNr', 'Date', 'Ini_Prep_Date', 'Prep_SOP', 'SerialNr', 'SerNr', 'Date_1', 'SondeAge', 'Solutions', 'Volume_Cathode', 'ByPass_Cell', 'Current_10min_after_
# ...

# %%
dfmeta = pd.read_excel("/home/poyraden/Analysis/JOSIEfiles/JOSIE_Table_2017_summary_upd.xlsx")
print(list(dfmeta))
# Out:
# ['Sim', 'Simulator Run #', 'Date', 'Team', 'Initial Prep Date', 'Prep SOP', 'serial #', 'ENSCI', 'sernr', 'Date.1', 'sondeage', 'Solutions', 'Sol', 'Buf', 'Volume Cathode', 'ByPass Cell', 'current 10 min after no ozone', ' Resp Time 4-1.5 (sec)', 'Resp Time  1min/2min (mircroamps)?', 'Final BG', 'iB0', 'iB1', 'iB2', 'T100', 'ml/min', 'T100 post', 'ml/min.1', ' Resp Time 4-1.5 (sec).1', 'Resp Time  1min/2min (microamps)', 'post test solution lost (grams)', 'pump motor current', 'pump motor current (post)', 'PF_Unc', 'PF_Cor', 'BG']

# %%
dfmeta[['Date','Sim','Team','Prep SOP', 'serial #', 'Solutions', 'ml/min','Sol', 'Buf', 'Volume Cathode','iB0', 'iB1', 'iB2', 'post test solution lost (grams)','T100', 'ml/min', 'T100 post', ]]
# Out:
#           Date  Sim  Team                      Prep SOP serial #  \
# 0   10/11/2017  171     1                       Vaisala  6A33216
# 1   10/11/2017  171     2                       Wallops  6A33298
# 2   10/11/2017  171     3                        SHADOZ   Z29456
# 3   10/11/2017  171     4               NOAA -No_bypass   Z29452
# 4   10/12/2017  172     1                       Vaisala  6A33211
# ..         ...  ...   ...                           ...      ...
# 79   11/2/2017  190     8  WMO-SOP 1.0 SHADOZ expansion  2Z31525
# 80   11/2/2017  191     5                       Vaisala  6A32265
# 81   11/2/2017  191     6            Changfeng (?ENSCI)  2Z31506
# 82   11/2/2017  191     7                    La Reunion  2Z31510
# 83   11/2/2017  191     8             Fujiwara (?ENSCI)  2Z31503
#
#              Solutions  ml/min  Sol  Buf  Volume Cathode   iB0   iB1   iB2  \
# 0            1.0%-1.0B  237.72  1.0  1.0             2.5  0.02  0.15  0.02
# ...

# %%
df0 = pd.read_csv("/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie2017_Data_2023paper_ib2.csv")
# Out:
# /home/poyraden/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (16,41,51) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(list(df0))
# Out:
# ['Unnamed: 0', 'Tact', 'Tsim', 'Pair', 'Tair', 'Tinlet', 'IM', 'TPint', 'TPext', 'PFcor', 'I_Pump', 'PO3', 'VMRO3', 'PO3_OPM', 'VMRO3_OPM', 'ADif_PO3S', 'RDif_PO3S', 'Z', 'Header_Team', 'Header_Sim', 'Header_PFunc', 'Header_PFcor', 'Header_IB1', 'Sim', 'Simulator_RunNr', 'Date', 'Team', 'Ini_Prep_Date', 'Prep_SOP', 'SerialNr', 'ENSCI', 'SerNr', 'Date_1', 'SondeAge', 'Solutions', 'Sol', 'Buf', 'Volume_Cathode', 'ByPass_Cell', 'Current_10min_after_noO3', 'Resp_Time_4_1p5_sec', 'RespTime_1minOver2min', 'Final_BG', 'iB0', 'iB1', 'iB2', 'T100', 'mlOvermin', 'T100_post', 'mlOverminp1', 'RespTime_4_1p5_sec_p1', 'RespTime_1minOver2min_microamps', 'PostTestSolution_Lost_gr', 'PumpMotorCurrent', 'PumpMotorCurrent_Post', 'PF_Unc', 'PF_Cor', 'BG', 'unc_Tpump', 'Tpump_cor', 'unc_Tpump_cor', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'plog', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'I_OPM_jma', 'I_OPM_kom', 'PO3_calc', 'PO3_dqa', 
# ...

# %%
df0[[ 'SerialNr', 'ENSCI', 'SerNr', 'Date', 'Team', 'Ini_Prep_Date','Header_PFunc', 'Header_PFcor','PFcor', 'iB0', 'iB1', 'iB2']]
# Out:
#        SerialNr  ENSCI  SerNr        Date  Team Ini_Prep_Date  Header_PFunc  \
# 0       6A33301      0  33301  10/20/2017     2    10/14/2017         3.533
# 1       6A33301      0  33301  10/20/2017     2    10/14/2017         3.533
# 2       6A33301      0  33301  10/20/2017     2    10/14/2017         3.533
# 3       6A33301      0  33301  10/20/2017     2    10/14/2017         3.533
# 4       6A33301      0  33301  10/20/2017     2    10/14/2017         3.533
# ...         ...    ...    ...         ...   ...           ...           ...
# 296267  2Z32856      1  32856  10/30/2017     6    10/28/2017         3.532
# 296268  2Z32856      1  32856  10/30/2017     6    10/28/2017         3.532
# 296269  2Z32856      1  32856  10/30/2017     6    10/28/2017         3.532
# 296270  2Z32856      1  32856  10/30/2017     6    10/28/2017         3.532
# 296271  2Z32856      1  32856  10/30/2017     6    10/28/2017         3.532
#
#         Header_PFcor    PFcor   iB0   iB1   iB2
# ...

# %%
df = pd.read_csv(f'/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie2017_calibrated_sm_hv.csv')
# Out:
# /home/poyraden/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (58,78,85) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#         Unnamed: 0  Unnamed: 0.1  Sim  Team   iB0   iB1   iB2  ENSCI  Sol  \
# 0                0         11565  184     7  0.03  0.07  0.09      1  0.5
# 1                1         11566  184     7  0.03  0.07  0.09      1  0.5
# 2                2         11567  184     7  0.03  0.07  0.09      1  0.5
# 3                3         11568  184     7  0.03  0.07  0.09      1  0.5
# 4                4         11569  184     7  0.03  0.07  0.09      1  0.5
# ...            ...           ...  ...   ...   ...   ...   ...    ...  ...
# 237066      237066        285763  181     1  0.00  0.01  0.03      0  1.0
# 237067      237067        285764  181     1  0.00  0.01  0.03      0  1.0
# 237068      237068        285765  181     1  0.00  0.01  0.03      0  1.0
# 237069      237069        285766  181     1  0.00  0.01  0.03      0  1.0
# 237070      237070        285767  181     1  0.00  0.01  0.03      0  1.0
#
#         ADX  ...   PO3_cor  ADif_pre  RDif_pre  ADif_pre_cor  RDif_pre_cor  \
# ...

# %%
dff=pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie2017_Data_Public.csv')

# %%
print(list(dff))
# Out:
# ['Unnamed: 0', 'Sim_Time', 'Data_Index', 'Pair_Pressure_ESC', 'Tair_Pressure_ESC', 'IM_Cell_Measured', 'IS_Cell_Slow', 'IF_Cell_Fast', 'IFDS_Cell_Fast_Deconv_Smooth', 'Pump_T_Ext', 'Pump_T_Int', 'Absorption_Eff', 'Pump_Eff_Conv', 'Conversion_Eff_Conv', 'Pump_Eff_TRCC', 'Conversion_Eff_TRCC', 'PO3_Conv', 'PO3_TRC', 'PO3_TRCC', 'PO3_OPM', 'Unc_PO3_Conv', 'Unc_PO3_TRC', 'Unc_PO3_TRCC', 'Unc_PO3_OPM']

# %%
dff = dff.drop(['Unnamed: 0'], axis=1)

# %%
dff
# Out:
#         Sim_Time  Data_Index  Pair_Pressure_ESC  Tair_Pressure_ESC  \
# 0            0.0         0.0          999.99900            299.151
# 1            2.0         2.0          999.99900            299.183
# 2            4.0         4.0          999.99900            299.170
# 3            6.0         6.0          999.99900            299.157
# 4            8.0         8.0          996.58300            298.923
# ...          ...         ...                ...                ...
# 237066    6992.0      6992.0            7.73468            214.838
# 237067    6994.0      6994.0            7.73188            214.766
# 237068    6996.0      6996.0            7.72909            214.693
# 237069    6998.0      6998.0            7.73608            214.874
# 237070    7000.0      7000.0            7.73608            214.874
#
#         IM_Cell_Measured  IS_Cell_Slow  IF_Cell_Fast  \
# 0                1.14041      1.140410      1.114816
# ...

# %%
pre = '_sm_hv'

# %%
df17c = pd.read_csv(f"/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie2017_deconv_2023paper_ib2{pre}.csv", low_memory=False)

# %%
print(list(df17c))
# Out:
# ['Unnamed: 0', 'index', 'Unnamed: 0.1', 'Tact', 'Tsim', 'Pair', 'Tair', 'Tinlet', 'IM', 'TPint', 'TPext', 'PFcor', 'I_Pump', 'PO3', 'VMRO3', 'PO3_OPM', 'VMRO3_OPM', 'ADif_PO3S', 'RDif_PO3S', 'Z', 'Header_Team', 'Header_Sim', 'Header_PFunc', 'Header_PFcor', 'Header_IB1', 'Sim', 'Simulator_RunNr', 'Date', 'Team', 'Ini_Prep_Date', 'Prep_SOP', 'SerialNr', 'ENSCI', 'SerNr', 'Date_1', 'SondeAge', 'Solutions', 'Sol', 'Buf', 'Volume_Cathode', 'ByPass_Cell', 'Current_10min_after_noO3', 'Resp_Time_4_1p5_sec', 'RespTime_1minOver2min', 'Final_BG', 'iB0', 'iB1', 'iB2', 'T100', 'mlOvermin', 'T100_post', 'mlOverminp1', 'RespTime_4_1p5_sec_p1', 'RespTime_1minOver2min_microamps', 'PostTestSolution_Lost_gr', 'PumpMotorCurrent', 'PumpMotorCurrent_Post', 'PF_Unc', 'PF_Cor', 'BG', 'unc_Tpump', 'Tpump_cor', 'unc_Tpump_cor', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'plog', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'I_OPM_jma', 'I_OPM_kom'
# ...

# %%
dftc = df17c[(df17c.Sim == 178) & (df17c.Team ==1)]

# %%
df = pd.read_csv(f'/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie2017_calibrated{pre}.csv')
# Out:
# /home/poyraden/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (58,78,85) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(list(df))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'Sim', 'Team', 'iB0', 'iB1', 'iB2', 'ENSCI', 'Sol', 'ADX', 'Buf', 'PO3', 'PO3_OPM', 'Tsim', 'Pair', 'IM', 'I_OPM_kom', 'I_OPM_jma', 'PFcor', 'TPext', 'Tpump_cor', 'unc_Tpump_cor', 'unc_Tpump', 'Tpump_cor.1', 'unc_Tpump_cor.1', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'PO3_calc', 'PO3_dqa', 'I_slow_conv_ib1_decay', 'Ifast_minib0_deconv', 'Ifast_minib0_deconv_ib1_decay', 'Ifast_minib0', 'Ifast_minib0_ib1_decay', 'Islow_conv', 'Ifast_deconv_ib1_decay', 'Ifast_minib0_deconv_sm10', 'Year', 'Unnamed: 0.1.1', 'index', 'Tact', 'Tair', 'Tinlet', 'TPint', 'I_Pump', 'VMRO3', 'VMRO3_OPM', 'ADif_PO3S', 'RDif_PO3S', 'Z', 'Header_Team', 'Header_Sim', 'Header_PFunc', 'Header_PFcor', 'Header_IB1', 'Simulator_RunNr', 'Date', 'Ini_Prep_Date', 'Prep_SOP', 'SerialNr', 'SerNr', 'Date_1', 'SondeAge', 'Solutions', 'Volume_Cathode', 'ByPass_Cell', 'Current_10min_after_
# ...

# %%
# print(df.drop_duplicates(['Sim','Team'])[['Sim','Team']])

# %%
dft = df[(df.Sim == 178) & (df.Team ==1)]

# %%
dft[['Tsim', 'Pair','Tair','IM','I_conv_slow','Ifast_minib0_deconv_sm10']]
# Out:
#           Tsim       Pair     Tair       IM  I_conv_slow  \
# 219994     0.0  999.99900  296.951  1.12820     1.128200
# 219995     2.0  999.12700  296.994  1.12413     1.128167
# 219996     4.0  999.47600  296.977  1.11599     1.128135
# 219997     6.0  999.82500  296.960  1.11966     1.128131
# 219998     8.0  994.65700  297.051  1.12169     1.128137
# ...        ...        ...      ...      ...          ...
# 223490  6992.0    7.89849  213.727  1.98535     3.467395
# 223491  6994.0    7.90268  213.723  1.97192     3.465419
# 223492  6996.0    7.89010  213.736  1.96174     3.463446
# 223493  6998.0    7.89010  213.736  1.97069     3.461475
# 223494  7000.0    7.89010  213.736  1.95360     3.459507
#
#         Ifast_minib0_deconv_sm10
# 219994                  0.000000
# 219995                  1.091282
# 219996                  1.090789
# 219997                  1.090824
# 219998                  1.090491
# ...                          ...
# 223490                  1.780513
# ...

# %%
dftc[['Tsim', 'Pair','Tair','IM','I_conv_slow','Ifast_minib0','Ifast_minib0_deconv_sm10','TPext','TPint']]
# Out:
#           Tsim       Pair     Tair       IM  I_conv_slow  Ifast_minib0  \
# 189225     0.0  999.99900  296.951  1.12820     1.128200      1.103008
# 189226     2.0  999.12700  296.994  1.12413     1.128167      1.101943
# 189227     4.0  999.47600  296.977  1.11599     1.128135      1.100930
# 189228     6.0  999.82500  296.960  1.11966     1.128131      1.100012
# 189229     8.0  994.65700  297.051  1.12169     1.128137      1.099147
# ...        ...        ...      ...      ...          ...           ...
# 192721  6992.0    7.89849  213.727  1.98535     3.467395      1.882783
# 192722  6994.0    7.90268  213.723  1.97192     3.465419      1.875887
# 192723  6996.0    7.89010  213.736  1.96174     3.463446      1.871576
# 192724  6998.0    7.89010  213.736  1.97069     3.461475      1.868637
# 192725  7000.0    7.89010  213.736  1.95360     3.459507      1.866403
#
#         Ifast_minib0_deconv_sm10    TPext   TPint
# 189225                  0.000000  300.165  299.62
# ...
