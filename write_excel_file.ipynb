# %%
import numpy as np
import pandas as pd
from constant_variables import *

# %%
dft = pd.read_excel('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie0910_EN1010_file.xlsx')

# %%
print(list(dft))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Sim', 'Team', 'iB0', 'iB1', 'iB2', 'ENSCI', 'Sol', 'ADX', 'Buf', 'PO3', 'PO3_OPM', 'Tsim', 'Pair', 'IM', 'I_OPM_kom', 'I_OPM_jma', 'PFcor', 'TPext', 'Tpump_cor', 'unc_Tpump_cor', 'unc_Tpump', 'Tpump_cor.1', 'unc_Tpump_cor.1', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'PO3_calc', 'PO3_dqa', 'Ifast_minib0_deconv', 'Ifast_minib0_deconv_ib1_decay', 'Ifast_minib0_deconv_sm10', 'Year', 'IMminusIB0', 'Islow', 'Islow_conv', 'Ifast', 'Ifast_minib0', 'Ifast_deconv', 'ADif', 'RDif', 'ADif_cor', 'RDif_cor', 'PO3_cor', 'ADif_pre', 'RDif_pre', 'ADif_pre_cor', 'RDif_pre_cor', 'IminusiB1', 'R', 'I_corrected', 'ADif_cal', 'RDif_cal', 'PO3_cal']

# %%
dft[['RDif', 'RDif_pre', 'RDif_cor','RDif_pre_cor','RDif_cal' ]]
# Out:
#             RDif   RDif_pre   RDif_cor  RDif_pre_cor   RDif_cal
# 0     -93.806944 -93.806944 -10.989988    -10.989988 -14.312139
# 1     -92.194016 -92.194016  -8.947432     -8.947432 -12.345818
# 2     -85.607686 -85.607686 -26.618466    -26.618466 -29.357310
# 3     -77.482411 -77.482411 -12.508390    -12.508390 -15.773869
# 4     -74.634871 -74.634871   5.102520      5.102520   1.179743
# ...          ...        ...        ...           ...        ...
# 82867   7.001211   7.001211   4.032981      4.032981  -7.208268
# 82868  10.204545  10.204545  15.155005     15.155005   2.712147
# 82869  21.380990  21.380990  20.262573     20.262573   7.261128
# 82870  26.410608  26.410608  26.906721     26.906721  13.189147
# 82871  26.538445  26.538445  17.678823     17.678823   4.960712
#
# [82872 rows x 5 columns]

# %%
['Unnamed: 0.2', 'Unnamed: 0', 'Sim', 'Team', 'iB0', 'iB1', 'iB2', 'ENSCI', 'Sol', 'ADX', 'Buf', 'PO3', 
 'PO3_OPM', 'Tsim', 'Pair', 'IM', 'I_OPM_kom', 'I_OPM_jma', 'PFcor', 'TPext', 'Tpump_cor', 'unc_Tpump_cor',
 'unc_Tpump', 'Tpump_cor.1', 'unc_Tpump_cor.1', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom',
 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'PO3_calc', 'PO3_dqa',
 'Ifast_minib0_deconv', 'Ifast_minib0_deconv_ib1_decay', 'Ifast_minib0_deconv_sm10', 'Year',
 'Unnamed: 0.1', 'index', 'Tact', 'Tair', 'Tinlet', 'TPint', 'I_Pump', 'VMRO3', 'VMRO3_OPM', 
 'ADif_PO3S', 'RDif_PO3S', 'Z', 'Header_Team', 'Header_Sim', 'Header_PFunc', 'Header_PFcor', 
 'Header_IB1', 'Simulator_RunNr', 'Date', 'Ini_Prep_Date', 'Prep_SOP', 'SerialNr', 'SerNr', 'Date_1', 
 'SondeAge', 'Solutions', 'Volume_Cathode', 'ByPass_Cell', 'Current_10min_after_noO3', 'Resp_Time_4_1p5_sec',
 'RespTime_1minOver2min', 'Final_BG', 'T100', 'mlOvermin', 'T100_post', 'mlOverminp1', 'RespTime_4_1p5_sec_p1',
 'RespTime_1minOver2min_microamps', 'PostTestSolution_Lost_gr', 'PumpMotorCurrent', 'PumpMotorCurrent_Post',
 'PF_Unc', 'PF_Cor', 'BG', 'plog', 'Tcell', 'TcellC', 'Pw', 'massloss', 'Tboil', 'total_massloss', 
 'I_conv_slow', 'I_conv_slow_komhyr', 'TS', 'IMminusIB0', 'Islow', 'Islow_conv', 'Ifast', 'Ifast_minib0', 
 'Ifast_deconv', 'ADif', 'RDif', 'ADif_cor', 'RDif_cor', 'PO3_cor', 'ADif_pre', 'RDif_pre', 'ADif_pre_cor', 
 'RDif_pre_cor', 'IminusiB1', 'R', 'I_corrected', 'ADif_cal', 'RDif_cal']

# %%
df = pd.read_csv("/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie0910_calibrated.csv", low_memory=False)

# %%
df[[ ]]
# Out:
#         RespTime_1minOver2min_microamps  PostTestSolution_Lost_gr  \
# 0                                   NaN                       NaN
# 1                                   NaN                       NaN
# 2                                   NaN                       NaN
# 3                                   NaN                       NaN
# 4                                   NaN                       NaN
# ...                                 ...                       ...
# 274921                              NaN                       NaN
# 274922                              NaN                       NaN
# 274923                              NaN                       NaN
# 274924                              NaN                       NaN
# 274925                              NaN                       NaN
#
#         PumpMotorCurrent  PumpMotorCurrent_Post  PF_Unc  PF_Cor  BG  plog  \
# 0                    NaN                    NaN     NaN     NaN NaN   NaN
# ...

# %%
de = pd.read_excel('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie0910_EN1010_file.xlsx')

# %%
de
# Out:
#        Unnamed: 0  Unnamed: 0.2  Unnamed: 0.1  Sim  Team   iB0   iB1    iB2  \
# 0           49738         49738         97986  140     1  0.02  0.05  0.040
# 1           49739         49739         97987  140     1  0.02  0.05  0.040
# 2           49740         49740         97988  140     1  0.02  0.05  0.040
# 3           49741         49741         97989  140     1  0.02  0.05  0.040
# 4           49742         49742         97990  140     1  0.02  0.05  0.040
# ...           ...           ...           ...  ...   ...   ...   ...    ...
# 82867      132605        132605        488203  147     4  0.01  0.02  0.015
# 82868      132606        132606        488204  147     4  0.01  0.02  0.015
# 82869      132607        132607        488205  147     4  0.01  0.02  0.015
# 82870      132608        132608        488206  147     4  0.01  0.02  0.015
# 82871      132609        132609        488207  147     4  0.01  0.02  0.015
#
# ...

# %%
dft = df.drop(['Unnamed: 0.1', 'index', 'Tact', 'Tair', 'Tinlet', 'TPint', 'I_Pump', 'VMRO3', 'VMRO3_OPM', 
 'ADif_PO3S', 'RDif_PO3S','Z', 'Header_Team', 'Header_Sim', 'Header_PFunc', 'Header_PFcor', 
 'Header_IB1', 'Simulator_RunNr', 'Date', 'Ini_Prep_Date', 'Prep_SOP', 'SerialNr', 'SerNr', 'Date_1', 
 'SondeAge', 'Solutions', 'Volume_Cathode', 'ByPass_Cell', 'Current_10min_after_noO3', 'Resp_Time_4_1p5_sec','RespTime_1minOver2min', 'Final_BG', 'T100', 'mlOvermin', 'T100_post', 'mlOverminp1', 'RespTime_4_1p5_sec_p1','RespTime_1minOver2min_microamps', 'PostTestSolution_Lost_gr', 'PumpMotorCurrent', 'PumpMotorCurrent_Post',
 'PF_Unc', 'PF_Cor', 'BG', 'plog', 'Tcell', 'TcellC','Unnamed: 0.1.1', 'Pw', 'massloss', 'Tboil', 'total_massloss', 'I_conv_slow', 'I_conv_slow_komhyr', 'TS'], axis=1)

# %%
print(list(dft))
# Out:
# ['Unnamed: 0', 'Sim', 'Team', 'iB0', 'iB1', 'iB2', 'ENSCI', 'Sol', 'ADX', 'Buf', 'PO3', 'PO3_OPM', 'Tsim', 'Pair', 'IM', 'I_OPM_kom', 'I_OPM_jma', 'PFcor', 'TPext', 'Tpump_cor', 'unc_Tpump_cor', 'unc_Tpump', 'Tpump_cor.1', 'unc_Tpump_cor.1', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'PO3_calc', 'PO3_dqa', 'Ifast_minib0_deconv', 'Ifast_minib0_deconv_ib1_decay', 'Ifast_minib0_deconv_sm10', 'Year', 'IMminusIB0', 'Islow', 'Islow_conv', 'Ifast', 'Ifast_minib0', 'Ifast_deconv', 'ADif', 'RDif', 'ADif_cor', 'RDif_cor', 'PO3_cor', 'ADif_pre', 'RDif_pre', 'ADif_pre_cor', 'RDif_pre_cor', 'IminusiB1', 'R', 'I_corrected', 'ADif_cal', 'RDif_cal']

# %%
dft[['ADif', 'RDif', 'ADif_cor', 'RDif_cor', 'PO3_cor', 'ADif_pre', 'RDif_pre', 'ADif_pre_cor', 'RDif_pre_cor', 'IminusiB1', 'R', 'I_corrected', 'ADif_cal', 'RDif_cal']]
# Out:
#             ADif       RDif  ADif_cor   RDif_cor   PO3_cor  ADif_pre  \
# 0      -0.026486  -2.764197 -0.009741  -1.016646  3.802622 -0.106192
# 1      -0.031097  -3.240872 -0.001823  -0.189966  3.839766 -0.124679
# 2      -0.047937  -4.909705 -0.021442  -2.196185  3.828593 -0.192194
# 3      -0.051760  -5.263112 -0.048564  -4.938373  3.748193 -0.207520
# 4      -0.056425  -5.719824 -0.034086  -3.455470  3.818390 -0.226222
# ...          ...        ...       ...        ...       ...       ...
# 274921  0.073303   6.073156  0.075217   6.955644  5.162013  0.293109
# 274922  0.127255  11.040293  0.096427   9.337504  5.039368  0.508847
# 274923  0.194423  18.246434  0.173912  18.223852  5.037247  0.777439
# 274924  0.210674  20.330331  0.233646  25.172391  5.186323  0.842356
# 274925  0.234884  23.041931  0.107581  11.781123  4.555662  0.939078
#
#          RDif_pre  ADif_pre_cor  RDif_pre_cor  IminusiB1         R  \
# 0       -2.764197     -0.039056     -1.016646   0.931684  1.675300
# ...
