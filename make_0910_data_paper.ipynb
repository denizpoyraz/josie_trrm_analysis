# %%
import pandas as pd
import numpy as np

# %%
dfc = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie0910_calibrated_sm_hv_publicdata.csv')

# %%
print(list(dfc))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'Sim', 'Team', 'iB0', 'iB1', 'iB2', 'ENSCI', 'Sol', 'ADX', 'Buf', 'PO3', 'PO3_OPM', 'Tsim', 'Pair', 'IM', 'I_OPM_kom', 'I_OPM_jma', 'PFcor', 'TPext', 'Tpump_cor', 'unc_Tpump_cor', 'unc_Tpump', 'Tpump_cor.1', 'unc_Tpump_cor.1', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'PO3_calc', 'PO3_dqa', 'I_slow_conv_ib1_decay', 'Ifast_minib0_deconv', 'Ifast_minib0_deconv_ib1_decay', 'Ifast_minib0', 'Ifast_minib0_ib1_decay', 'Islow_conv', 'Ifast_deconv_ib1_decay', 'Ifast_minib0_deconv_sm10', 'Year', 'Unnamed: 0.1.1', 'index', 'Tact', 'Tair', 'Tinlet', 'TPint', 'I_Pump', 'VMRO3', 'VMRO3_OPM', 'ADif_PO3S', 'RDif_PO3S', 'Z', 'Header_Team', 'Header_Sim', 'Header_PFunc', 'Header_PFcor', 'Header_IB1', 'Simulator_RunNr', 'Date', 'Ini_Prep_Date', 'Prep_SOP', 'SerialNr', 'SerNr', 'Date_1', 'SondeAge', 'Solutions', 'Volume_Cathode', 'ByPass_Cell', 'Current_10min_after_
# ...

# %%
dfc[['Tsim']]
# Out:
#           Tsim
# 0         56.0
# 1         72.0
# 2         74.0
# 3         76.0
# 4         80.0
# ...        ...
# 283606  8092.0
# 283607  8094.0
# 283608  8096.0
# 283609  8098.0
# 283610  8100.0
#
# [283611 rows x 1 columns]

# %%
df09c = pd.read_csv(f"/home/poyraden/Analysis/JOSIEfiles/Proccessed/"
                    f"Josie0910_deconv_2023_unitedpaper_sm_hv.csv",low_memory=False)

# %%
print(list(df09c))
# Out:
# ['Unnamed: 0', 'Sim', 'Team', 'iB0', 'iB1', 'iB2', 'ENSCI', 'Sol', 'ADX', 'Buf', 'PO3', 'PO3_OPM', 'Tsim', 'Pair', 'IM', 'I_OPM_kom', 'I_OPM_jma', 'PFcor', 'TPext', 'Tpump_cor', 'unc_Tpump_cor', 'unc_Tpump', 'Tpump_cor.1', 'unc_Tpump_cor.1', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'PO3_calc', 'PO3_dqa', 'I_slow_conv_ib1_decay', 'Ifast_minib0_deconv', 'Ifast_minib0_deconv_ib1_decay', 'Ifast_minib0', 'Ifast_minib0_ib1_decay', 'Islow_conv', 'Ifast_deconv_ib1_decay']

# %%
df09c[['Tsim']]
# Out:
#            Tsim
# 0           0.0
# 1           2.0
# 2           4.0
# 3           6.0
# 4           8.0
# ...         ...
# 489652  10990.0
# 489653  10992.0
# 489654  10994.0
# 489655  10996.0
# 489656  10998.0
#
# [489657 rows x 1 columns]

# %%
dfc[['Tsim','Tsim_original']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_17053/2588310910.py in <module>
# ----> 1 dfc[['Tsim','Tsim_original']]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
dfca = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie0910_calibrated_sm_hv_all.csv')

# %%
print(list(dfca))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'index', 'Tact', 'Tsys', 'Sim', 'TimeBool', 'TimeTag', 'IM', 'Team', 'I_OPM_kom', 'I_OPM_jma', 'iB0', 'iB1', 'iB2', 'ENSCI', 'Sol', 'Buf', 'ADX', 'Tsim', 'Pair', 'TPext', 'PFcor', 'PO3', 'PO3_OPM', 'Year', 'unc_Tpump', 'Tpump_cor', 'unc_Tpump_cor', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'plog', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'PO3_calc', 'PO3_dqa', 'Time_ts', 'Time_all', 'Tsim_original', 'Tsim_pctime', 'PF', 'TS', 'IMminusIB0', 'Tsim_min', 'decay_time', 'tmp', 'IM_gsm', 'IMminusIB0_gsm', 'i_at_timeib1', 'time_ib1', 'start_flight', 'I_slow', 'I_slow_conv', 'I_fast', 'Ifast_minib0', 'Ifast_deconv', 'Ifast_minib0_deconv', 'Ifast_minib0_deconv_sm10', 'I_slow_conv_ib1_decay_all', 'I_fast_ib1_decay_all', 'Ifast_minib0_ib1_decay_all', 'Ifast_deconv_ib1_decay_all', 'Ifast_minib0_deconv_ib1_decay_all', 'IminusiB1', 'R', 'I_corrected']

# %%
dfca[dfca.Sim==167][['Sim','Team','Tsim','Tsim_original','TimeTag', 'Pair','PO3_OPM','IM','I_corrected','Ifast_minib0_deconv_sm10','Ifast_minib0_deconv_ib1_decay_all','decay_time','TPext', 'Tpump_cor']]
# Out:
#         Sim  Team     Tsim  Tsim_original TimeTag     Pair   PO3_OPM  \
# 6468    167     1      0.0            NaN    Prep      NaN       NaN
# 6469    167     1      3.0            NaN    Prep      NaN       NaN
# 6470    167     1      6.0            NaN    Prep      NaN       NaN
# 6471    167     1      8.0            NaN    Prep      NaN       NaN
# 6472    167     1     11.0            NaN    Prep      NaN       NaN
# ...     ...   ...      ...            ...     ...      ...       ...
# 620636  167     4  14672.0        12526.0     Sim  999.999 -100.2177
# 620637  167     4  14674.0        12528.0     Sim  999.999 -100.2177
# 620638  167     4  14676.0        12530.0     Sim  999.999 -100.2177
# 620639  167     4  14678.0        12532.0     Sim  999.999 -100.2177
# 620640  167     4  14680.0        12534.0     Sim  999.999 -100.2177
#
#               IM  I_corrected  Ifast_minib0_deconv_sm10  \
# 6468    0.017094          NaN                  0.000000
# ...

# %%
dfc= pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie0910_calibrated_sm_hv.csv')

# %%
dfc= pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie0910_calibrated_sm_hv.csv')

# %%
dfu = pd.read_csv(f"/home/poyraden/Analysis/JOSIEfiles/Proccessed/"
                    f"Josie0910_deconv_2023_unitedpaper_sm_hv.csv",low_memory=False)

# %%
dfu2 = pd.read_csv(f"/home/poyraden/Analysis/JOSIEfiles/Proccessed/"
                    f"Josie0910_deconv_2023_unitedpaper_sm_hv_test.csv",low_memory=False)

# %%
len(dfu.drop_duplicates(['Sim','Team'])), len(dfu2.drop_duplicates(['Sim','Team'])), 


# len(dfc.drop_duplicates(['Sim','Team'])),len(dfp.drop_duplicates(['Sim','Team'])), len(dfs.drop_duplicates(['Sim','Team']))
# Out:
# (86, 86)

# %%
df1 = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie0910_preparationadded_2023paper.csv')
len(df1.drop_duplicates(['Sim','Team']))
# Out:
# 80

# %%
df = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie0910_Deconv_preparationadded_all_2023paper_sm_hv_paper.csv')
# Out:
# 82

# %%
dfp = pd.read_csv("/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie0910_Deconv_preparationadded_all_2023paper_sm_hv_paper.csv")

# %%
print(list(dfp))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'index', 'Tact', 'Tsys', 'Sim', 'TimeBool', 'TimeTag', 'IM', 'Team', 'I_OPM_kom', 'I_OPM_jma', 'iB0', 'iB1', 'iB2', 'ENSCI', 'Sol', 'Buf', 'ADX', 'Tsim', 'Pair', 'TPext', 'PFcor', 'PO3', 'PO3_OPM', 'Year', 'unc_Tpump', 'Tpump_cor', 'unc_Tpump_cor', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'plog', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'PO3_calc', 'PO3_dqa', 'Time_ts', 'Time_all', 'Tsim_original', 'Tsim_pctime', 'PF', 'TS', 'IMminusIB0', 'Tsim_min', 'decay_time', 'tmp', 'IM_gsm', 'IMminusIB0_gsm', 'i_at_timeib1', 'time_ib1', 'start_flight', 'I_slow', 'I_slow_conv', 'I_fast', 'Ifast_minib0', 'Ifast_deconv', 'Ifast_minib0_deconv', 'Ifast_minib0_deconv_sm10', 'I_slow_conv_ib1_decay_all', 'I_fast_ib1_decay_all', 'Ifast_minib0_ib1_decay_all', 'Ifast_deconv_ib1_decay_all', 'Ifast_minib0_deconv_ib1_decay_all']

# %%
dfp[(dfp.Sim ==140) & (dfp.Team==1)][['Tsim','Tsim_original','IM','Ifast_minib0_deconv_ib1_decay_all','TimeTag']]
# Out:
#            Tsim  Tsim_original        IM  Ifast_minib0_deconv_ib1_decay_all  \
# 136387      0.0            NaN  0.012210                           0.000000
# 136388      3.0            NaN  0.012210                          -0.007531
# 136389      6.0            NaN  0.012210                          -0.007805
# 136390      8.0            NaN  0.012210                          -0.008287
# 136391     11.0            NaN  0.014652                          -0.008476
# ...         ...            ...       ...                                ...
# 153417  34371.0        11334.0  0.297110                           0.183498
# 153418  34373.0        11336.0  0.295482                           0.189262
# 153419  34375.0        11338.0  0.293040                           0.195314
# 153420  34377.0        11340.0  0.283272                           0.201139
# 153421  34379.0        11342.0  0.282458                           0.206246
#
#        TimeTag
# 136387    Prep
# 136388    Prep
# ...

# %%
dfs[(dfs.Sim ==140) & (dfs.Team==1) & (dfs.Tsim_original>=0)][['Tsim','Tsim_original','Pair','Ifast_minib0_deconv_ib1_decay']]
# Out:
#            Tsim  Tsim_original     Pair  Ifast_minib0_deconv_ib1_decay
# 103493  23039.0            0.0  997.315                       0.000000
# 103494  23041.0            2.0  999.328                      -0.002904
# 103495  23043.0            4.0  998.657                      -0.002886
# 103496  23045.0            6.0  997.986                      -0.002854
# 103497  23047.0            8.0  999.999                      -0.002781
# ...         ...            ...      ...                            ...
# 109160  34371.0        11334.0  995.362                       0.183496
# 109161  34373.0        11336.0  995.362                       0.189261
# 109162  34375.0        11338.0  995.362                       0.195312
# 109163  34377.0        11340.0  995.362                       0.201138
# 109164  34379.0        11342.0  995.362                       0.206245
#
# [5672 rows x 4 columns]

# %%
len(dfp.drop_duplicates(['Sim','Team'])),len(dfs.drop_duplicates(['Sim','Team']))
# Out:
# (78, 78)

# %%
print(list(dfp))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'index', 'Tact', 'Tsys', 'Sim', 'TimeBool', 'TimeTag', 'IM', 'Team', 'I_OPM_kom', 'I_OPM_jma', 'iB0', 'iB1', 'iB2', 'ENSCI', 'Sol', 'Buf', 'ADX', 'Tsim', 'Pair', 'TPext', 'PFcor', 'PO3', 'PO3_OPM', 'Year', 'unc_Tpump', 'Tpump_cor', 'unc_Tpump_cor', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'plog', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'PO3_calc', 'PO3_dqa', 'Time_ts', 'Time_all', 'Tsim_original', 'Tsim_pctime', 'PF', 'TS', 'IMminusIB0', 'Tsim_min', 'decay_time', 'tmp', 'IM_gsm', 'IMminusIB0_gsm', 'i_at_timeib1', 'time_ib1', 'start_flight', 'I_slow', 'I_slow_conv', 'I_fast', 'Ifast_minib0', 'Ifast_deconv', 'Ifast_minib0_deconv', 'Ifast_minib0_deconv_sm10', 'I_slow_conv_ib1_decay_all', 'I_fast_ib1_decay_all', 'Ifast_minib0_ib1_decay_all', 'Ifast_deconv_ib1_decay_all', 'Ifast_minib0_deconv_ib1_decay_all']

# %%
dfp[(dfp.Sim ==138) & (dfp.Team==3) & (dfp.Tsim>=3740)][['Tsim','Tsim_original','Pair','IM','Ifast_minib0_deconv_ib1_decay_all']]
# Out:
#            Tsim  Tsim_original     Pair        IM  \
# 395211   3740.0            NaN      NaN  0.000000
# 395212   3742.0            NaN      NaN  0.000000
# 395213   3744.0            NaN      NaN  0.000000
# 395214   3746.0            NaN      NaN  0.000000
# 395215   3747.0            0.0  995.118  0.031746
# ...         ...            ...      ...       ...
# 400676  14667.0        10922.0  999.999  0.053724
# 400677  14669.0        10924.0  999.999  0.048840
# 400678  14671.0        10926.0  999.999  0.048840
# 400679  14673.0        10928.0  999.999  0.048840
# 400680  14675.0        10930.0  999.999  0.046398
#
#         Ifast_minib0_deconv_ib1_decay_all
# 395211                          -0.011253
# 395212                           0.004207
# 395213                           0.020169
# 395214                           0.032800
# 395215                           0.038172
# ...                                   ...
# 400676                          -0.238185
# ...

# %%
dfs = pd.read_csv("/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie0910_Deconv_preparationadded_simulation_2023paper_sm_hv_paper.csv")

# %%
print(list(dfs))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'index', 'Tact', 'Tsys', 'Sim', 'TimeBool', 'TimeTag', 'IM', 'Team', 'I_OPM_kom', 'I_OPM_jma', 'iB0', 'iB1', 'iB2', 'ENSCI', 'Sol', 'Buf', 'ADX', 'Tsim', 'Pair', 'TPext', 'PFcor', 'PO3', 'PO3_OPM', 'Year', 'unc_Tpump', 'Tpump_cor', 'unc_Tpump_cor', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'plog', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'PO3_calc', 'PO3_dqa', 'Time_ts', 'Time_all', 'Tsim_original', 'Tsim_pctime', 'PF', 'TS', 'IMminusIB0', 'tmp', 'IM_gsm', 'IMminusIB0_gsm', 'i_at_timeib1', 'time_ib1', 'decay_time', 'start_flight', 'I_slowo', 'I_slow_convo', 'I_fasto', 'Ifast_minib0o', 'Ifast_deconvo', 'Ifast_minib0_deconvo', 'Ifast_minib0_deconv_sm10', 'I_slow_ib1_decay', 'I_slow_conv_ib1_decay', 'I_fast_ib1_decay', 'Ifast_minib0_ib1_decay', 'Ifast_deconv_ib1_decay', 'Ifast_minib0_deconv_ib1_decay', 'Ifast_minib0_deconv_ib1_decay_sm10', 'I_slow_ib1_test', 'I_slow_conv_ib1_test', 'I_fas
# ...

# %%
# Out:
#            Tsim  Tsim_original     Pair  Ifast_minib0_deconv_ib1_decay
# 286771   3747.0            0.0  995.118                       0.000000
# 286772   3749.0            2.0  995.118                      -0.004804
# 286773   3751.0            4.0  995.118                      -0.005488
# 286774   3753.0            6.0  995.118                      -0.006474
# 286775   3755.0            8.0  995.327                      -0.007451
# ...         ...            ...      ...                            ...
# 292232  14667.0        10922.0  999.999                      -0.238162
# 292233  14669.0        10924.0  999.999                      -0.179306
# 292234  14671.0        10926.0  999.999                      -0.123441
# 292235  14673.0        10928.0  999.999                      -0.082704
# 292236  14675.0        10930.0  999.999                      -0.058213
#
# [5466 rows x 4 columns]

# %%
year = '2010'

# Read the metadata and data files
dfm = pd.read_csv(f"/home/poyraden/Analysis/JOSIEfiles/Josie{year[2:4]}_MetaData.csv")
dfm_ib = pd.read_excel(f"/home/poyraden/Analysis/JOSIEfiles/ib_{year}.xlsx")
dfm_m = pd.read_excel(f"/home/poyraden/Analysis/JOSIEfiles/{year}_mass.xlsx")

# %%
print(list(dfm))
# Out:
# ['Year', 'Sim', 'Team', 'Code', 'Flow', 'IB1', 'Cor', 'ENSCI', 'Sol', 'Buf', 'ADX']

# %%
print(list(dfm_ib))
# Out:
# ['Sim', 'Team', 'Year', 'iB0', 'iB1', 'iB2']

# %%
print(list(dfm_m))
# Out:
# ['Sim', 'Team', 'Mspre', 'MSpost', 'Diff']

# %%
dfm_m
# Out:
#     Sim  Team   Mspre  MSpost   Diff
# 0   150     1  215.08  212.63   2.45
# 1   150     2  215.53  213.02   2.51
# 2   150     3  265.06  203.67  61.39
# 3   150     4  203.74  202.65   1.09
# 4   151     1  216.14  213.51   2.63
# 5   151     2  214.97  212.12   2.85
# 6   151     3  203.89  202.66   1.23
# 7   151     4  196.26  194.87   1.39
# 8   158     1  629.68  628.00   1.68
# 9   158     2    0.00    0.00   0.00
# 10  158     3  622.55  621.29   1.26
# 11  158     4  612.66  611.43   1.23
# 12  159     1  630.35  628.36   1.99
# 13  159     2  629.85  627.97   1.88
# 14  159     3  621.97  620.89   1.08
# 15  159     4  619.53  618.36   1.17
# 16  160     1  631.00  628.66   2.34
# 17  160     2  628.60  627.62   0.98
# 18  160     3  621.55  620.54   1.01
# 19  160     4  633.96  632.96   1.00
# 20  161     1  629.64  627.82   1.82
# 21  161     2  629.66  627.68   1.98
# 22  161     3    0.00    0.00   0.00
# 23  161     4  611.91  610.97   0.94
# ...

# %%
dff = pd.read_csv("/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie0910_Data_2023paper.csv")
# Out:
# /home/poyraden/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(list(dff))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'Tact', 'Tsim', 'Pair', 'Tair', 'Tinlet', 'IM', 'TPint', 'TPext', 'PFcor', 'I_Pump', 'PO3', 'VMRO3', 'PO3_OPM', 'VMRO3_OPM', 'ADif_PO3S', 'RDif_PO3S', 'Z', 'Header_Team', 'Header_Sim', 'Header_PFunc', 'Header_PFcor', 'Header_IB1', 'Year', 'Sim', 'Team', 'Code', 'Flow', 'IB1', 'Cor', 'ENSCI', 'Sol', 'Buf', 'ADX', 'Simib', 'Teamib', 'Yearib', 'iB0', 'iB1', 'iB2', 'Simm', 'Teamm', 'Mspre', 'Mspost', 'Diff', 'unc_Tpump', 'Tpump_cor', 'unc_Tpump_cor', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'plog', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'I_OPM_jma', 'I_OPM_kom', 'PO3_calc', 'PO3_dqa', 'I_conv_slow', 'I_conv_slow_komhyr']

# %%
dfa = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie9602_Data_2023.csv')

# %%
print(list(dfa))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'RecNr', 'Time', 'Tsim', 'Pair', 'Tair', 'Temp_TMC_Ist_1', 'Altitude', 'PO3_OPM', 'I_Sonde', 'T_Sonde', 'PO3_Sonde_raw', 'PO3_Sonde_Corr', 'PO3_Sonde_TCO3', 'O3_Col_corr', 'O3_Col_OPM', 'Valid', 'Sim', 'Team', 'PF_min', 'iB', 'TOCS', 'TOCO', 'PF', 'PFcor', 'TPext', 'IM', 'unc_Tpump', 'Tpump_cor', 'unc_Tpump_cor', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Sol', 'Buf', 'ENSCI', 'iB0', 'iB1', 'ib1-ib0', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'plog', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'I_OPM_jma', 'I_OPM_kom', 'PO3_calc', 'PO3_dqa', 'JOSIE_Nr', 'PO3', 'TPint', 'I_conv_slow', 'R1_Tstart', 'R1_Tstop', 'R2_Tstart', 'R2_Tstop', 'SST_Nr', 'SondeTypeNr']

# %%
dfa[(dfa.Sim==89) & (dfa.Team==3)][['Pair','Tair','Temp_TMC_Ist_1','T_Sonde']]
# Out:
#              Pair  Tair  Temp_TMC_Ist_1  T_Sonde
# 108386  997.86000   NaN             NaN      NaN
# 108387  997.08300   NaN             NaN      NaN
# 108388  996.30500   NaN             NaN      NaN
# 108389  995.52700   NaN             NaN      NaN
# 108390  994.75000   NaN             NaN      NaN
# ...           ...   ...             ...      ...
# 111251    6.31644   NaN             NaN      NaN
# 111252    6.31763   NaN             NaN      NaN
# 111253    6.31881   NaN             NaN      NaN
# 111254    6.31990   NaN             NaN      NaN
# 111255    6.31990   NaN             NaN      NaN
#
# [2870 rows x 4 columns]

# %%
df96 = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie1996_Data_2023.csv')

# %%
print(list(df96))
# Out:
# ['Unnamed: 0', 'RecNr', 'Time', 'Tsim', 'Pair', 'Tair', 'Temp_TMC_Ist_1', 'Altitude', 'PO3_OPM', 'I_Sonde', 'T_Sonde', 'PO3_Sonde_raw', 'PO3_Sonde_Corr', 'PO3_Sonde_TCO3', 'O3_Col_corr', 'O3_Col_OPM', 'Valid', 'Sim', 'Team', 'PF_min', 'iB', 'TOCS', 'TOCO', 'PF', 'PFcor', 'TPext', 'IM', 'unc_Tpump', 'Tpump_cor', 'unc_Tpump_cor', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Sol', 'Buf', 'ENSCI', 'iB0', 'iB1', 'ib1-ib0', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'plog', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'I_OPM_jma', 'I_OPM_kom', 'PO3_calc', 'PO3_dqa']

# %%
df96[['Pair','Tair']]
# Out:
#           Pair     Tair
# 0      1013.15  299.620
# 1      1011.25  300.490
# 2      1008.42  301.575
# 3      1005.65  302.167
# 4      1002.80  302.590
# ...        ...      ...
# 28073      NaN      NaN
# 28074      NaN      NaN
# 28075      NaN      NaN
# 28076      NaN      NaN
# 28077      NaN      NaN
#
# [28078 rows x 2 columns]

# %%
df96[[ 'Sim', 'Team']].max(), df96[[ 'Sim', 'Team']].min()
# Out:
# (Sim     36.0
#  Team     6.0
#  dtype: float64,
#  Sim     25.0
#  Team     3.0
#  dtype: float64)

# %%
df98 = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie1998_Data_2023.csv')

# %%
df98[[ 'Sim', 'Team']].max(), df98[[ 'Sim', 'Team']].min()
# Out:
# (Sim     57
#  Team    26
#  dtype: int64,
#  Sim     51
#  Team     1
#  dtype: int64)

# %%
df20 = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie2000_Data_2023.csv')

# %%
df20[[ 'Sim', 'Team']].max(), df20[[ 'Sim', 'Team']].min()
# Out:
# (Sim     102
#  Team      7
#  dtype: int64,
#  Sim     89
#  Team     1
#  dtype: int64)

# %%
df22 = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie2002_Data_2023.csv')

# %%
df22[[ 'Sim', 'Team']].max(), df20[[ 'Sim', 'Team']].min()
# Out:
# (Sim     114
#  Team      4
#  dtype: int64,
#  Sim     89
#  Team     1
#  dtype: int64)

# %%
dfmeta = pd.read_excel("/home/poyraden/Analysis/JOSIEfiles/JOSIE-96-02/Josie_2000_metadata.xls")
dfmeta
# Out:
#     JOSIE_Nr  Sim_Nr  R1_Tstart  R1_Tstop  R2_Tstart  R2_Tstop  \
# 0       2000      89        960      1170       3240      3420
# 1       2000      89        960      1170       3240      3420
# 2       2000      89        960      1170       3240      3420
# 3       2000      89        960      1170       3240      3420
# 4       2000      90        860      1140       3250      3400
# 5       2000      90        860      1140       3250      3400
# 6       2000      90        860      1140       3250      3400
# 7       2000      90        860      1140       3250      3400
# 8       2000      91        925      1100       4060      4235
# 9       2000      91        925      1100       4060      4235
# 10      2000      91        925      1100       4060      4235
# 11      2000      91        925      1100       4060      4235
# 12      2000      92       1030      1210       4040      4215
# 13      2000      92       1030      1210       4040      4215
# ...

# %%
dfc = pd.read_csv(f'/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie9602_calibrated_sm_hv.csv')

# %%
print(list(dfc))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.2', 'index', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'RecNr', 'Time', 'Tsim', 'Pair', 'Tair', 'Temp_TMC_Ist_1', 'Altitude', 'PO3_OPM', 'I_Sonde', 'T_Sonde', 'PO3_Sonde_raw', 'PO3_Sonde_Corr', 'PO3_Sonde_TCO3', 'O3_Col_corr', 'O3_Col_OPM', 'Valid', 'Sim', 'Team', 'PF_min', 'iB', 'TOCS', 'TOCO', 'PF', 'PFcor', 'TPext', 'IM', 'unc_Tpump', 'Tpump_cor', 'unc_Tpump_cor', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Sol', 'Buf', 'ENSCI', 'iB0', 'iB1', 'ib1-ib0', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'plog', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'I_OPM_jma', 'I_OPM_kom', 'PO3_calc', 'PO3_dqa', 'JOSIE_Nr', 'PO3', 'TPint', 'I_conv_slow', 'R1_Tstart', 'R1_Tstop', 'R2_Tstart', 'R2_Tstop', 'SST_Nr', 'SondeTypeNr', 'IMminusIB0', 'tmp', 'IM_gsm', 'IMminusIB0_gsm', 'Islow', 'Islow_conv', 'Ifast', 'Ifast_minib0', 'Ifast_deconv', 'Ifast_minib0_deconv', 'Ifast_minib0_deconv_sm10', 'Year', 'IminusiB1', 'R', 'I_corrected', 'ADif', 'RDif', 'ADif_cor', '
# ...

# %%
df = pd.read_csv(f"/home/poyraden/Analysis/JOSIEfiles/Proccessed/Josie0910_Data_2023paper.csv")
# Out:
# /home/poyraden/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(list(df))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'Tact', 'Tsim', 'Pair', 'Tair', 'Tinlet', 'IM', 'TPint', 'TPext', 'PFcor', 'I_Pump', 'PO3', 'VMRO3', 'PO3_OPM', 'VMRO3_OPM', 'ADif_PO3S', 'RDif_PO3S', 'Z', 'Header_Team', 'Header_Sim', 'Header_PFunc', 'Header_PFcor', 'Header_IB1', 'Year', 'Sim', 'Team', 'Code', 'Flow', 'IB1', 'Cor', 'ENSCI', 'Sol', 'Buf', 'ADX', 'Simib', 'Teamib', 'Yearib', 'iB0', 'iB1', 'iB2', 'Simm', 'Teamm', 'Mspre', 'Mspost', 'Diff', 'unc_Tpump', 'Tpump_cor', 'unc_Tpump_cor', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'plog', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'I_OPM_jma', 'I_OPM_kom', 'PO3_calc', 'PO3_dqa', 'I_conv_slow', 'I_conv_slow_komhyr']

# %%
df[['Team','Sim','Mspre', 'Mspost']]
# Out:
#         Team  Sim   Mspre  Mspost
# 0          1  139  794.30  790.83
# 1          1  139  794.30  790.83
# 2          1  139  794.30  790.83
# 3          1  139  794.30  790.83
# 4          1  139  794.30  790.83
# ...      ...  ...     ...     ...
# 547627     2  165  629.67  627.62
# 547628     2  165  629.67  627.62
# 547629     2  165  629.67  627.62
# 547630     2  165  629.67  627.62
# 547631     2  165  629.67  627.62
#
# [547632 rows x 4 columns]

# %%
df.Mspre.round(2)
# Out:
# 0         794.30
# 1         794.30
# 2         794.30
# 3         794.30
# 4         794.30
#            ...
# 547627    629.67
# 547628    629.67
# 547629    629.67
# 547630    629.67
# 547631    629.67
# Name: Mspre, Length: 547632, dtype: float64

# %%
print(list(dfc))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'Sim', 'Team', 'iB0', 'iB1', 'iB2', 'ENSCI', 'Sol', 'ADX', 'Buf', 'PO3', 'PO3_OPM', 'Tsim', 'Pair', 'IM', 'I_OPM_kom', 'I_OPM_jma', 'PFcor', 'TPext', 'Tpump_cor', 'unc_Tpump_cor', 'unc_Tpump', 'Tpump_cor.1', 'unc_Tpump_cor.1', 'deltat', 'unc_deltat', 'deltat_ppi', 'unc_deltat_ppi', 'Cpf_kom', 'unc_Cpf_kom', 'Cpf', 'unc_Cpf', 'Cpf_jma', 'unc_Cpf_jma', 'PFcor_kom', 'PFcor_jma', 'PO3_calc', 'PO3_dqa', 'I_slow_conv_ib1_decay', 'Ifast_minib0_deconv', 'Ifast_minib0_deconv_ib1_decay', 'Ifast_minib0', 'Ifast_minib0_ib1_decay', 'Islow_conv', 'Ifast_deconv_ib1_decay', 'Ifast_minib0_deconv_sm10', 'Year', 'Unnamed: 0.1.1', 'index', 'Tact', 'Tair', 'Tinlet', 'TPint', 'I_Pump', 'VMRO3', 'VMRO3_OPM', 'ADif_PO3S', 'RDif_PO3S', 'Z', 'Header_Team', 'Header_Sim', 'Header_PFunc', 'Header_PFcor', 'Header_IB1', 'Simulator_RunNr', 'Date', 'Ini_Prep_Date', 'Prep_SOP', 'SerialNr', 'SerNr', 'Date_1', 'SondeAge', 'Solutions', 'Volume_Cathode', 'ByPass_Cell', 'Current_10min_after_
# ...

# %%
df1 = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Paper/2017/173_1.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_17053/2812881788.py in <module>
# ----> 1 df1 = pd.read_csv('/home/poyraden/Analysis/JOSIEfiles/Paper/2017/173_1.csv')
#
# ~/.local/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
